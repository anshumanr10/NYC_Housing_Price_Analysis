# %% [markdown]
# # NYC Housing Sales – Beginner Starter Notebook
#
# ## Instructions
# 1. Run this notebook to automatically download the dataset.
# 2. The dataset will load into a Pandas DataFrame called `df`.
# 3. Perform your analysis below.
# 4. Create visualizations and insights for your video presentation.

# %%
# ---------------------------
# Install gdown if needed
# ---------------------------
# %pip install gdown --quiet
# %pip install pandas --quiet

# ---------------------------
# Imports
# ---------------------------
import gdown
import pandas as pd
import os

# ---------------------------
# Step 0: Workspace path (cloud vs local)
# On Databricks: absolute /Workspace/Users/<user>/
# Locally: project data/ folder
# ---------------------------
WORKSPACE_USER = "anshumanr10@gmail.com"
if os.environ.get("DATABRICKS_RUNTIME_VERSION"):
    workspace_folder = f"/Workspace/Users/{WORKSPACE_USER}/"
else:
    workspace_folder = os.path.join(os.getcwd(), "data")
os.makedirs(workspace_folder, exist_ok=True)

# ---------------------------
# Step 1: Download CSV
# ---------------------------
url = "https://drive.google.com/uc?id=1s8CFPP6wh8LomYOOQX83T6IE1JOf_HhI"
output = os.path.join(workspace_folder, "nyc_housing_base.csv")

print("Downloading NYC Housing dataset to your workspace folder...")
gdown.download(url, output, quiet=False)
print("Download complete!")

# ---------------------------
# Step 2: Load CSV into Pandas
# ---------------------------
df = pd.read_csv(output, encoding="latin1", engine="python")
print("Dataset loaded successfully!")
print("Shape:", df.shape)
df.head()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1s8CFPP6wh8LomYOOQX83T6IE1JOf_HhI
# To: /home/anshu/Github-Repositories/NYC_Housing_Price_Analysis/data/nyc_housing_base.csv
# 100%|██████████| 3.81M/3.81M [00:00<00:00, 12.4MB/s]
# Download complete!
# Dataset loaded successfully!
# Shape: (34439, 19)
#    borough_x  block  lot  sale_price  zip_code borough_y  yearbuilt  lotarea  \
# 0          1    400   11      280000   10009.0        MN     1900.0   2404.0
# 1          1    402   36     2000000   10009.0        MN     1900.0   1919.0
# 2          1    402   60     3400000   10009.0        MN     1920.0   2150.0
# 3          1    404   42     4000000   10009.0        MN     1855.0   2369.0
# 4          1    372   55      655000   10009.0        MN     1920.0   5298.0
#
# ...
